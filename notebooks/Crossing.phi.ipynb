# %% [markdown]
# # Quantile crossing validation of direct GPQR models for phi

# %%
import sys
import os

import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0, os.path.abspath(".."))

try:
    import config_notebook
except ImportError:
    print("Output will not be deterministic SVG.")

# %% [markdown]
# ## Load data

# %%
crossing = pd.read_csv("../_temp/crossing.DirectMTGPQR_phi.csv")

# %% [markdown]
# ## Plot

# %%
plt.plot(crossing["crossing_rate_0"], label="Target 1")
plt.plot(crossing["crossing_rate_1"], label="Target 2")
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Crossing Rate")
plt.legend()
plt.show()

# %%
plt.plot(crossing["mean_crossing_0"], label="Target 1")
plt.plot(crossing["mean_crossing_1"], label="Target 2")
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Mean crossing")
plt.legend()
plt.show()

# %%
plt.plot(crossing["max_crossing_0"], label="Target 1")
plt.plot(crossing["max_crossing_1"], label="Target 2")
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Max crossing")
plt.legend()
plt.show()
